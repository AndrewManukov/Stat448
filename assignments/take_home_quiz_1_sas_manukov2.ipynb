# %% [markdown]
# ## Take-Home Quiz - SAS
#
# Grading Rubric (per question):
# 2 points if complete and correct
# 1 point if incomplete or incorrect
# 0 points if no attempt made
#
# The following questions should be completed with you by yourself, thus you are the *designated submitter* (who must submit (commit/push) the answers to the take home quiz in your repo. The deadline to submit this quiz is **9:00 am Monday March 2, 2020**. Do not change anything in this file above the line.
#
# ***
#
# **#0** Pull this ipynb file from your respective **assignments_section_sp20** repo; either **assignments_section2_sp20** or **assignments_section3_sp20**. Copy it into your personal repo to begin answering the questions, but rename the file as take_home_quiz_1_sas_Netid.ipynb with your Netid. (GitHub)
#
# ***

# %% [markdown]
# **#1** Using Markdown syntax (not SAS syntax), make a bulleted list that has your first name in italic font in one bullet and your last name in bold font in another bullet. (Markdown)

# %% [markdown]
# * *Andro* <br>
# * **Manukov**

# %% [markdown]
# **#2** Using Markdown syntax (not SAS syntax), make a numbered list that has 3 items. Number 1 should contain a hyperlink for the STAT 448 course website (not the GitHub Enterprise site). Number 2 should contain the URL of the STAT 448 course website and my email address as links. Number 3 should contain a blockquote of the STAT 448 course information which appears in the syllabus. (Markdown, Syllabus)

# %% [markdown]
# 1.  [Stat 448 Website](http://publish.illinois.edu/kinson2/teaching/stat-448/)
# 2.  [http://publish.illinois.edu/kinson2/teaching/stat-448/](http://publish.illinois.edu/kinson2/teaching/stat-448/) [kinson2@illinois.edu](kinson2@illinois.edu)
# 3. > Advanced Data Analysis (STAT 448) is a very broad analytics course that aims to cover several topics in statistics and data science and to apply these methodologies in statistical computing software including SAS and R. The topics in the course include descriptive statistics and inference, visualizations, exploratory data analysis, and modeling. The expectation is that students will become proficient data analysts who understand how to explain statistical results as well as how to craft narratives with data using SAS and R. Critical (and statistical) thinking and captivating design will be pushed as well as written and oral presentation of findings. This course aims to push students to investigate problems and employ aspects of the investigative process for data analysis with a special focus on visualizations and data exploration.

# %% [markdown]
# **#3** Using the visualization below, describe what's happening in the plot. (Data Visualization, Markdown)
# ![](https://uofi.box.com/shared/static/fa95r5o558q61llcldkctjvijwy7sy7o.jpg)

# %% [markdown]
# Its a scarf lmao. The different colors explain how long each delay was and it is incremented by day. I believe the red is the longest delay and the other colors signify smaller delays. I thought the long strip of red was interesting as it really signified how terrible the public transport system was. (in germany?)

# %% [markdown]
# **#4** Using Markdown syntax (not SAS syntax) and the visualization below, make two separate numbered lists. The first list contains 2 items that are good about the visualization. The second list contains 2 items that you would suggest as changes in order to improve the plot. (Markdown, Visual Design Principles, Data Visualization)
# ![](https://uofi.box.com/shared/static/ggmu0rlojjzup8rf97f593ywkqyfg5c5.png)

# %% [markdown]
# Good:
#     1.  Has all the labels (title, xlab, ylab)
#     2.  Has colors so you can tell apart the different points
#     3.  Has mean lat/long
#
#
# Improve:
#     1. Add some landmark points such as Chicago. Latitude and Longitude are not intuitive
#     2. The color scheme is terrible. Why are the latitude mean/longitude mean purple and yellow? It would be good to make the color scheme much more visually appealing. One place to start would be making the points softer.
#     3. Split the one plot into three based on the risk factor. This plot is very clustered.

# %% [markdown]
# **#5** Import only the 1st, 10th, and 20th parts of the 2015 US Natality Data, keeping only the variables in the list below (not case sensitive). After importing, merge the 3 data sets into 1 single data set called **nat**. *You must use the options statement to prevent extaneous SAS output for this problem.* (SAS, Accessing and Importing Data, Data Wrangling)
#
#   - M_Ht_In
#   - BMI
#   - PWgt_R
#   - DWgt_R
#   - RF_PDIAB
#   - RF_GDIAB
#   - RF_PHYPE
#   - RF_GHYPE
#   - RF_EHYPE
#   - RF_PPTERM
#   - RF_CESAR
#   - ME_PRES
#   - ATTEND
#   - PAY_REC
#   - APGAR5
#   - APGAR10
#   - AB_NICU
#   - BFED
#   - priorlive
#   - priordead
#   - mrace6
#   - frace6
#   - dplural
#   - OEGest_R3
#   - SEX
#   - MAGER
#   - FAGECOMB
#   - MEDUC
#   - FEDUC
#   - PREVIS_REC
#   - previs
#   - CIG_REC
#   - WTGAIN
#   - DMETH_REC
#   - dbwt

# %%
options nosource nonotes errors=0;
filename nat1 url "https://uofi.box.com/shared/static/gb07nz7jafspk65wzxq6awlu02kypiq7.csv" termstr=crlf;
filename nat10 url "https://uofi.box.com/shared/static/xf7r94alpzaqv4wxh5liqw7rpk21wb6l.csv" termstr=crlf;
filename nat20 url "https://uofi.box.com/shared/static/eq9k4d73ansal5p8mspu3mpslmzs7x8g.csv" termstr=crlf;
proc import datafile=nat1 out=birth01(keep = M_Ht_In BMI PWgt_R DWgt_R RF_PDIAB RF_GDIAB RF_PHYPE RF_GHYPE RF_EHYPE RF_PPTERM RF_CESAR ME_PRES ATTEND PAY_REC APGAR5 APGAR10 AB_NICU BFED priorlive priordead mrace6 frace6 dplural OEGest_R3 SEX MAGER FAGECOMB MEDUC FEDUC PREVIS_REC previs CIG_REC WTGAIN DMETH_REC dbwt) replace dbms=csv; 
run;
proc import datafile=nat10 out=birth10(keep = M_Ht_In BMI PWgt_R DWgt_R RF_PDIAB RF_GDIAB RF_PHYPE RF_GHYPE RF_EHYPE RF_PPTERM RF_CESAR ME_PRES ATTEND PAY_REC APGAR5 APGAR10 AB_NICU BFED priorlive priordead mrace6 frace6 dplural OEGest_R3 SEX MAGER FAGECOMB MEDUC FEDUC PREVIS_REC previs CIG_REC WTGAIN DMETH_REC dbwt) replace dbms=csv; 
run;
proc import datafile=nat20 out=birth20(keep = M_Ht_In BMI PWgt_R DWgt_R RF_PDIAB RF_GDIAB RF_PHYPE RF_GHYPE RF_EHYPE RF_PPTERM RF_CESAR ME_PRES ATTEND PAY_REC APGAR5 APGAR10 AB_NICU BFED priorlive priordead mrace6 frace6 dplural OEGest_R3 SEX MAGER FAGECOMB MEDUC FEDUC PREVIS_REC previs CIG_REC WTGAIN DMETH_REC dbwt) replace dbms=csv; 
run;
data nat;
 set birth01 birth10 birth20; 
 keep M_Ht_In BMI PWgt_R DWgt_R RF_PDIAB RF_GDIAB RF_PHYPE RF_GHYPE RF_EHYPE RF_PPTERM RF_CESAR ME_PRES ATTEND PAY_REC APGAR5 APGAR10 AB_NICU BFED priorlive priordead mrace6 frace6 dplural OEGest_R3 SEX MAGER FAGECOMB MEDUC FEDUC PREVIS_REC previs CIG_REC WTGAIN DMETH_REC dbwt;
run;
options source notes errors=20;
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//EN"
#    "http://www.w3.org/TR/html4/strict.dtd">
#
# <html>
# <head>
#   <title></title>
#   <meta http-equiv="content-type" content="text/html; charset=None">
#   <style type="text/css">
# td.linenos { background-color: #f0f0f0; padding-right: 10px; }
# span.lineno { background-color: #f0f0f0; padding: 0 5px 0 5px; }
# pre { line-height: 125%; }
# body .hll { background-color: #ffffcc }
# body  { background: #ffffff; }
# body .c { color: #0000FF } /* Comment */
# body .k { color: #ff0000; font-weight: bold } /* Keyword */
# body .n { color: #008000 } /* Name */
# body .ch { color: #0000FF } /* Comment.Hashbang */
# body .cm { color: #0000FF } /* Comment.Multiline */
# body .cp { color: #0000FF } /* Comment.Preproc */
# body .cpf { color: #0000FF } /* Comment.PreprocFile */
# body .c1 { color: #0000FF } /* Comment.Single */
# body .cs { color: #0000FF } /* Comment.Special */
# ...

# %% [markdown]
# **#6** Using SAS, delete (from the computer's memory) the 3 data sets that were imported in **Problem 5**. With the **nat** data that was created in **Problem 5**, remove any unknown or missing values. (SAS, Accessing and Importing Data, Data Wrangling)

# %%
proc delete data=birth01;
run;
proc delete data=birth10;
run;
proc delete data=birth20;
run;

data nat;
 set nat;
 if OEGest_R3 ne 3 and WTGAIN ne 99 and PREVIS ne 99 and MEDUC ne 9 and FAGECOMB ne 99 and FRACE6 ne 9 and FEDUC ne 9 and PRIORLIVE ne 99 and PRIORDEAD ne 99 and CIG_REC ne "U" and M_HT_IN ne 99 and BMI ne 99.9 and PWGT_R ne 999 and DWGT_R ne 999 and WTGAIN ne 99 and ME_PRES ne 9 and DMETH_REC ne 9 and ATTEND ne 9 and PAY_REC ne 9 and APGAR5 ne 99 and APGAR10 ne 99 and APGAR10 ne 88 and DBWT ne 9999 and AB_NICU ne "U" and BFED ne "U";
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//EN"
#    "http://www.w3.org/TR/html4/strict.dtd">
#
# <html>
# <head>
#   <title></title>
#   <meta http-equiv="content-type" content="text/html; charset=None">
#   <style type="text/css">
# td.linenos { background-color: #f0f0f0; padding-right: 10px; }
# span.lineno { background-color: #f0f0f0; padding: 0 5px 0 5px; }
# pre { line-height: 125%; }
# body .hll { background-color: #ffffcc }
# body  { background: #ffffff; }
# body .c { color: #0000FF } /* Comment */
# body .k { color: #ff0000; font-weight: bold } /* Keyword */
# body .n { color: #008000 } /* Name */
# body .ch { color: #0000FF } /* Comment.Hashbang */
# body .cm { color: #0000FF } /* Comment.Multiline */
# body .cp { color: #0000FF } /* Comment.Preproc */
# body .cpf { color: #0000FF } /* Comment.PreprocFile */
# body .c1 { color: #0000FF } /* Comment.Single */
# body .cs { color: #0000FF } /* Comment.Special */
# ...

# %% [markdown]
# **#7** Using SAS and beginning with the merged data in **Problem 6**, randomly select 30,000 observations with the PROC SURVEYSELECT and change the default seed number to be the last 4 digits of your UIN. Call this newly created data set **birthran**. (SAS, Accessing and Importing Data, Data Wrangling)

# %%
proc surveyselect data=nat method=srs n=30000 out=birthran seed=1670;
run;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %% [markdown]
# **#8** Using SAS and beginning with the **birthran** data in **Problem 7**, do the following wrangling processes.
#
#   - name this new data set **birth**
#   - create a new variable called "riskfactorbin" which equals 1 if the mother has any of the 7 risk factors and equals 0 otherwise
#   - create a new variable called "dbwtlbs" which equals the baby's birth weight in pounds
#   - drops all risk factor variables
#   - drops previs_rec
#
# Now show the first 10 observations of the **birth** data and the following columns: oegest_r3, previs, dbwtlbs, bmi, and attend. (SAS, Accessing and Importing Data, Data Wrangling)

# %%
data birth;
 set birthran;
 dbwtlbs = dbwt/454;
 if RF_PDIAB = "Y" or RF_GDIAB = "Y" or RF_PHYPE = "Y" or RF_GHYPE = "Y" or RF_EHYPE = "Y" or RF_PPTERM = "Y" or RF_CESAR = "Y" then riskfactorbin=1;
  else riskfactorbin=0;
  keep M_Ht_In BMI PWgt_R DWgt_R ME_PRES ATTEND PAY_REC APGAR5 APGAR10 AB_NICU BFED priorlive priordead mrace6 frace6 dplural OEGest_R3 SEX MAGER FAGECOMB MEDUC FEDUC previs CIG_REC WTGAIN DMETH_REC dbwt dbwtlbs;
run;

proc print data = birth (obs = 10);
var oegest_r3 previs dbwtlbs bmi attend;
run;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %% [markdown]
# **#9** Using SAS and beginning with the **birth** data in **Problem 8**, partition it to create a training data set (70% of the observations) and a testing data set (30% of the observations). These two new data sets must have been produced with randomization and with the last 4 digits of your UIN as the seed number again. Call the training set **birthtrn** and the testing set **birthtst**. (SAS, Accessing and Importing Data, Data Wrangling)

# %%
data birthtemp;
 set birth;
 call streaminit(1670); 
 n=rand('uniform');
run;

proc sort data=birthtemp;
 by n;
run;

data birthtrn birthtst;
 set birthtemp nobs=nobs;
 if _n_<=0.7*nobs then output birthtrn;
  else output birthtst;
run;
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//EN"
#    "http://www.w3.org/TR/html4/strict.dtd">
#
# <html>
# <head>
#   <title></title>
#   <meta http-equiv="content-type" content="text/html; charset=None">
#   <style type="text/css">
# td.linenos { background-color: #f0f0f0; padding-right: 10px; }
# span.lineno { background-color: #f0f0f0; padding: 0 5px 0 5px; }
# pre { line-height: 125%; }
# body .hll { background-color: #ffffcc }
# body  { background: #ffffff; }
# body .c { color: #0000FF } /* Comment */
# body .k { color: #ff0000; font-weight: bold } /* Keyword */
# body .n { color: #008000 } /* Name */
# body .ch { color: #0000FF } /* Comment.Hashbang */
# body .cm { color: #0000FF } /* Comment.Multiline */
# body .cp { color: #0000FF } /* Comment.Preproc */
# body .cpf { color: #0000FF } /* Comment.PreprocFile */
# body .c1 { color: #0000FF } /* Comment.Single */
# body .cs { color: #0000FF } /* Comment.Special */
# ...

# %%
proc print data = birthtrn (obs = 10);
run;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %% [markdown]
# **#10** Using SAS and beginning with the **birthtrn** data in **Problem 9**, recreate the data visualization below. *Obviously, each student's **birthtrn** and **birthtst** will be different.* (SAS, Data Visualization, Visual Design Principles)
#
# ![](https://uofi.box.com/shared/static/u47cbvrt9b4o5rzqq977idqsbdfi096l.png)

# %%
proc sgpanel data= birthtrn;
 panelby SEX / layout=columnlattice onepanel
          colheaderpos=bottom rows=1 novarname noborder;
 vbar OEGEST_R3 / stat=freq datalabel datalabelattrs=(size=12pt color=blue); 
run;

*Ugh close enough? ;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %% [markdown]
# **#11** Using SAS and beginning with the **birthtst** data in **Problem 9**, recreate the data visualization below. *Obviously, each student's **birthtrn** and **birthtst** will be different.* (SAS, Data Visualization, Visual Design Principles)
#
# ![](https://uofi.box.com/shared/static/uzla1knz6an54ldmcb3uajfo0jy7lma6.png)

# %%
**proc means;
**xaxis display noline;
*noborder noautolegend nowall;
proc means data=birthtst noprint;
 class previs;
 var wtgain;
 output out=seriesdata mean=avgweightgain;
run;

proc sgplot data=seriesdata noborder nowall;
 series x=previs y=avgweightgain;
 xaxis values=(0 10 20 30 40 50);
 yaxis values=(0 10 20 30 40 50);

title "Mother's avg weight gain across number of prenatal visits";
run;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %%
title
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//EN"
#    "http://www.w3.org/TR/html4/strict.dtd">
#
# <html>
# <head>
#   <title></title>
#   <meta http-equiv="content-type" content="text/html; charset=None">
#   <style type="text/css">
# td.linenos { background-color: #f0f0f0; padding-right: 10px; }
# span.lineno { background-color: #f0f0f0; padding: 0 5px 0 5px; }
# pre { line-height: 125%; }
# body .hll { background-color: #ffffcc }
# body  { background: #ffffff; }
# body .c { color: #0000FF } /* Comment */
# body .k { color: #ff0000; font-weight: bold } /* Keyword */
# body .n { color: #008000 } /* Name */
# body .ch { color: #0000FF } /* Comment.Hashbang */
# body .cm { color: #0000FF } /* Comment.Multiline */
# body .cp { color: #0000FF } /* Comment.Preproc */
# body .cpf { color: #0000FF } /* Comment.PreprocFile */
# body .c1 { color: #0000FF } /* Comment.Single */
# body .cs { color: #0000FF } /* Comment.Special */
# ...

# %% [markdown]
# **#12** Using SAS and beginning with the **birthtrn** data in **Problem 9**, determine if there are any outliers in the data. Give evidence as to which points are outliers and why they are outliers. If there are no outliers, give your reasoning for why there are no outliers in the data. (SAS, Data Descriptives, Data Visualization)

# %%
**ALL CONTINOIUS VARIABLES. 10 or sometihng MAGER MRACE6 MEDUC FAGECOMB DBWT PRIORLIVE PRIORDEAD PREVIS M_ht_IN BMI PWGT_R DWGT_R WTGAIN APGARS APGAR10 DBWT DBWTLBS;
**MAGER	MRACE6	MEDUC	FAGECOMB	FRACE6	FEDUC	PRIORLIVE	PRIORDEAD	PREVIS	CIG_REC	M_HT_IN	BMI	PWGT_R	DWGT_R	WTGAIN	ME_PRES	DMETH_REC	ATTEND	PAY_REC	APGAR5	APGAR10	DPLURAL	SEX	OEGEST_R3	DBWT	AB_NICU	BFED	dbwtlbs;
*	PREVIS M_HT_IN BMI PWGT_R DWGT_R WTGAIN APGAR5	APGAR10			DBWT		dbwtlbs;

proc sgplot data=birthtrn;
 vbox M_HT_IN;
run;

proc sgplot data=birthtrn;
 vbox PWGT_R;
run;

proc sgplot data=birthtrn;
 vbox BMI;
run;

proc sgplot data=birthtrn;
 vbox DWGT_R;
run;

proc sgplot data=birthtrn;
 vbox WTGAIN;
run;

proc sgplot data=birthtrn;
 vbox DBWT;
run;

proc sgplot data=birthtrn;
 vbox dbwtlbs;
run;

proc sgplot data=birthtrn;
 vbox APGAR5;
run;

proc sgplot data=birthtrn;
 vbox APGAR10;
run;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %% [markdown]
# Lets explain some outliers:
# M_HT_IN: Self Explanitory: Some people are taller/shorter than others
# PWGT_R: Some people are just weigh more
# BMI: Same reasoning
# DWGT_R: Same as above
# WTGAIN: People react differently to pregnancy weight gain
# DBWT: User error, Premature baby, some babies way more
# dbwtlbs: User error, Premature baby, some babies way more just in pounds
# APGAR5: no real outliers
# APGAR10: User error. Should be between 0-10. box plot is bad

# %% [markdown]
# **#13** Using SAS and beginning with the **birthtst** data in **Problem 9**, determine if there are any outliers in the data. Give evidence as to which points are outliers and why they are outliers. If there are no outliers, give your reasoning for why there are no outliers in the data. (SAS, Data Descriptives, Data Visualization)

# %%
**explain outside of;
proc sgplot data=birthtst;
 vbox M_HT_IN;
run;

proc sgplot data=birthtst;
 vbox PWGT_R;
run;

proc sgplot data=birthtst;
 vbox BMI;
run;

proc sgplot data=birthtst;
 vbox DWGT_R;
run;

proc sgplot data=birthtst;
 vbox WTGAIN;
run;

proc sgplot data=birthtst;
 vbox DBWT;
run;

proc sgplot data=birthtst;
 vbox dbwtlbs;
run;

proc sgplot data=birthtst;
 vbox APGAR5;
run;

proc sgplot data=birthtst;
 vbox APGAR10;
run;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %% [markdown]
# Lets explain some outliers:
# M_HT_IN: Self Explanitory: Some people are taller/shorter than others
# PWGT_R: Some people are just weigh more
# BMI: Same reasoning
# DWGT_R: Same as above
# WTGAIN: People react differently to pregnancy weight gain
# DBWT: User error, Premature baby, some babies way more
# dbwtlbs: User error, Premature baby, some babies way more just in pounds
# APGAR5: no real outliers
# APGAR10: User error. Should be between 0-10. box plot is bad

# %% [markdown]
# **#14** Using SAS and beginning with the **birth** data in **Problem 8**, conduct a principal components analysis (PCA) on the variables that are not categorical and not binary. Explain how many components to keep and give reasoning for that chosen number. *You must use ods select to limit the amount of SAS output.* (SAS, Principal Components Analysis, Data Visualization)

# %%
proc corr data=birth;
 var M_HT_IN PWGT_R BMI DWGT_R WTGAIN DBWT dbwtlbs APGAR5 APGAR10;
 ods select pearsoncorr;
run;

proc princomp data=birth out=pcbirth outstat=pcstatbirth;
 var M_HT_IN PWGT_R BMI DWGT_R WTGAIN DBWT dbwtlbs APGAR5 APGAR10;
 ods select Eigenvalues;
run;

data newbirth;
set pcstatbirth;
if _type_ = 'EIGENVAL'; /*only eigenvalues*/
array vars{9} M_HT_IN PWGT_R BMI DWGT_R WTGAIN DBWT dbwtlbs APGAR5 APGAR10 ;
avgEigenval=sum(of vars{*})/9;
run;
proc print data=newbirth;
run;
*/run;
**decrease variables that are highly correlated. 8 prolly or 3-5. CPF is larger than 85. 70%

**eigen values

**scree
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %% [markdown]
# I would keep 4 components because they have an Eigenvalue greater than 1.  In this case, the first 3 components to keep would be M_HT_IN PWGT_R BMI

# %% [markdown]
# **#15** Using SAS and the PCA results in **Problem 14**, give an interpretation of the first 3 components. This interpretation should be descriptive and should not include numeric descriptions of the values of the eigenvectors. Additionally, you must show visualizations of these first 3 components as evidence to go along with your interpretation. (SAS, Principal Components Analysis, Data Visualization)

# %%
***eigen vectors, pattern plot, explain first 3: PWGRTRN DBWT DBWTLBS apager5;
proc princomp data=birth out=pcbirth outstat=pcstatbirth plots=(pattern);
 var M_HT_IN PWGT_R BMI;
 ods select Eigenvectors  patternplot;
run;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %% [markdown]
# The first two plots of the pattern plot seem to suggest that component 1 to 2 and component 3 have averaging behavior

# %%
proc princomp data=birth out=pcbirth outstat=pcstatbirth plots=(score);
 var M_HT_IN PWGT_R BMI;
 ods select Eigenvectors  scoreplot;
run;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %% [markdown]
# The score plots help confirm that theory

# %% [markdown]
# **#16** Using SAS, use linear regression to predict a baby's birth weight in pounds (dbwtlbs). You must compare 2 sets of predictors to seek a better prediction. This problem requires the use of only **birthtrn** (building the model and testing how well it performs).
#
# Describe the results of the better model and how good it is at predicting a baby's birth weight. (SAS, GLM - Linear Regression, Data Visualization, Markdown)

# %%
proc corr data=birthtrn;
 var M_HT_IN PWGT_R BMI DWGT_R WTGAIN DBWT APGAR5 APGAR10;
 ods exclude simplestats;
run;
proc sgscatter data=birthtrn;
 matrix M_HT_IN PWGT_R BMI DWGT_R WTGAIN DBWT APGAR5 APGAR10;
run;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %%
proc reg data=birthtrn;
 model dbwtlbs =  M_HT_IN PWGT_R BMI DWGT_R WTGAIN APGAR10;
 ods select parameterestimates fitstatistics;
run;

proc genmod data=birthtrn;
 model dbwtlbs =  M_HT_IN PWGT_R BMI DWGT_R WTGAIN APGAR10 / dist=normal link=identity;
 ods select parameterestimates ;
run;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %%
proc reg data=birthtrn;
 model dbwtlbs = PWGT_R BMI DWGT_R WTGAIN ;
 ods select parameterestimates fitstatistics;
run;

proc genmod data=birthtrn;
 model dbwtlbs =PWGT_R BMI DWGT_R WTGAIN / dist=normal link=identity;
 ods select parameterestimates;
run;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %% [markdown]
# Both models are godawful at predicting the baby's weight. The first (full model) is slightly better at predicting as its adjusted R squared is slightly higher than the other model.

# %% [markdown]
# **#17** Using SAS, use poisson regression to predict a baby's birth weight in grams (dbwt). You must compare 2 sets of predictors to seek a better prediction. This problem requires the use of only **birthtrn** (building the model and testing how well it performs).
#
# Describe the results of the better model and how good it is at predicting a baby's birth weight. (SAS, GLM - Poisson Regression, Data Visualization, Markdown)

# %%
proc genmod data=birthtrn;
 model dbwt = M_HT_IN PWGT_R BMI DWGT_R WTGAIN DBWT APGAR5 APGAR10 / dist=poisson link=log;
 ods select parameterestimates;
run;

proc genmod data=birthtrn;
model dbwt = M_HT_IN PWGT_R BMI DWGT_R WTGAIN DBWT APGAR5 APGAR10  / dist=poisson link=log type1 type3;
 ods select modelfit type1 modelanova;
run;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %%
proc genmod data=birthtrn;
 model dbwt = M_HT_IN PWGT_R BMI WTGAIN DBWT APGAR10 / dist=poisson link=log;
 ods select parameterestimates;
run;

proc genmod data=birthtrn;
model dbwt = M_HT_IN PWGT_R BMI WTGAIN DBWT APGAR10  / dist=poisson link=log type1 type3;
 ods select modelfit type1 modelanova;
run;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %% [markdown]
# These models are also pretty bad at predicting the baby's weight in grams. The first model is much better since its AIC is lower. Just like R^2, AIC also includes a penalty for adding more parameters

# %% [markdown]
# **#18** Using SAS, use logistic regression to predict whether a baby is born prematurely or not (OEGest_R3). You must compare 2 sets of predictors to seek a better prediction. This problem requires the use of both **birthtrn** (building the model) and **birthtst** (testing how well it performs).
#
# Describe the results of the better model and how good it is at predicting if baby is born prematurely. (SAS, GLM - Logistic Regression, Data Visualization, Markdown)

# %%
proc logistic data=birthtrn;
 model OEGest_R3(event="1") = M_HT_IN PWGT_R BMI DWGT_R WTGAIN DBWT APGAR5 APGAR10;
 ods select parameterestimates;
run;

proc genmod data=birthtst;
 model OEGest_R3(event="1") = M_HT_IN PWGT_R BMI DWGT_R WTGAIN DBWT APGAR5 APGAR10 / dist=binomial link=logit;
 ods select parameterestimates modelfit type1 modelanova;
run;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %%
proc logistic data=birthtrn;
 model OEGest_R3(event="1") = M_HT_IN PWGT_R BMI DWGT_R APGAR5 APGAR10;
 ods select parameterestimates;
run;

proc genmod data=birthtst;
 model OEGest_R3(event="1") = M_HT_IN PWGT_R BMI DWGT_R APGAR5 APGAR10 / dist=binomial link=logit;
 ods select parameterestimates modelfit type1 modelanova;
run;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %% [markdown]
# The first model is better as it has a lower AIC. Better as in it's better than the other model. The first model is still meh because its AIC is still really high.

# %% [markdown]
# **#19** Using SAS, use linear discriminant analysis to predict whether a baby is born prematurely or not (OEGest_R3). You must compare 2 sets of predictors to seek a better prediction. This problem requires the use of both **birthtrn** (building the model) and **birthtst** (testing how well it performs).
#
# Describe the results of the better model and how good it is at predicting if baby is born prematurely. (SAS, Discriminant Analysis, Data Visualization, Markdown)

# %%
proc freq data=birthtrn;
 table OEGest_R3;
run;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %%
proc discrim data=birthtrn outstat=trainingsetrez pool=test manova testdata=birthtst testout=testingsetrez;
 class OEGest_R3;
 var DWGT_R;
 ods exclude logdet distgeneralized errorresub errortestclass classifiedresub classifiedtestclass;
run;

proc discrim data=birthtrn outstat=trainingsetrez pool=test manova testdata=birthtst testout=testingsetrez;
 class OEGest_R3;
 var DWGT_R;
 priors prop;
 ods exclude logdet distgeneralized errorresub errortestclass classifiedresub classifiedtestclass;
run;

proc discrim data=birthtrn outstat=trainingsetrez pool=test manova testdata=birthtst testout=testingsetrez;
 class OEGest_R3;
 var DWGT_R;
 ods select errorresub classifiedresub;
run;

proc discrim data=birthtrn outstat=trainingsetrez pool=test manova testdata=birthtst testout=testingsetrez;
 class OEGest_R3;
 var DWGT_R;
 priors prop;
 ods select errorresub classifiedresub;
run;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %% [markdown]
# This model is pretty decent. It has a cross-validation misclasification rate of .09 which is pretty good.

# %%
proc discrim data=birthtrn outstat=trainingsetrez pool=test manova testdata=birthtst testout=testingsetrez;
 class OEGest_R3;
 var DBWT;
 ods exclude logdet distgeneralized errorresub errortestclass classifiedresub classifiedtestclass;
run;

proc discrim data=birthtrn outstat=trainingsetrez pool=test manova testdata=birthtst testout=testingsetrez;
 class OEGest_R3;
 var DBWT;
 priors prop;
 ods exclude logdet distgeneralized errorresub errortestclass classifiedresub classifiedtestclass;
run;

proc discrim data=birthtrn outstat=trainingsetrez pool=test manova testdata=birthtst testout=testingsetrez;
 class OEGest_R3;
 var DBWT;
 ods select errorresub classifiedresub;
run;

proc discrim data=birthtrn outstat=trainingsetrez pool=test manova testdata=birthtst testout=testingsetrez;
 class OEGest_R3;
 var DBWT;
 priors prop;
 ods select errorresub classifiedresub;
run;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %% [markdown]
# This model is even better than the previous one. Its cross-validation misclasification rate is .06. This makes sense since weight seems like a good predictor to see if a baby was born premature.

# %% [markdown]
# **#20** Using SAS, use kNN classification to predict whether a baby is born prematurely or not (OEGest_R3). You must compare 2 sets of predictors to seek a better prediction. This problem requires the use of both **birthtrn** (building the model) and **birthtst** (testing how well it performs).
#
# Describe the results of the better model and how good it is at predicting if baby is born prematurely. (SAS, kNN Classification, Data Visualization, Markdown)

# %%
proc discrim data=birthtrn method=npar k=3 crossvalidate testdata=birthtst testout=testresults ;
 class OEGest_R3;
 var wtgain dbwt; 
 ods exclude errortestclass classifiedtestclass;
run;

proc discrim data=birthtrn method=npar k=3 crossvalidate testdata=birthtst testout=testresults ;
 class OEGest_R3;
 var wtgain dbwt;
 ods select errortestclass classifiedtestclass;
run;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %% [markdown]
# This model is okay, it has a cross-validation misclasification rate of .22 which is not as good as some of the previous models

# %%
proc discrim data=birthtrn method=npar k=3 crossvalidate testdata=birthtst testout=testresults ;
 class OEGest_R3;
 var wtgain dbwt BMI M_HT_IN; 
 ods exclude errortestclass classifiedtestclass;
run;

proc discrim data=birthtrn method=npar k=3 crossvalidate testdata=birthtst testout=testresults ;
 class OEGest_R3;
 var wtgain dbwt BMI M_HT_IN;
 ods select errortestclass classifiedtestclass;
run;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %% [markdown]
# This model is okay, it has a cross-validation misclasification rate of .20 which is about the same as the first model. I would use the first model as it has less parameters and yields just about the same results.

# %% [markdown]
# **#00** The **designated submitter** should commit and push the file to their repo with the commit message "All Done".
